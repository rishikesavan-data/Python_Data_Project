# %% [markdown]
# # Matplotlib : Box Plot

# %%
# Import Libraries
from datasets import load_dataset
import pandas as pd
import ast
import matplotlib.pyplot as plt

# Load Dataset
raw = load_dataset('lukebarousse/data_jobs')
data = raw['train'].to_pandas()
df = data.copy()

# Data Cleaning 
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)
df['job_skills'] = df['job_skills'].apply(lambda x : ast.literal_eval(x) if pd.notna(x) else x)

# %% [markdown]
# **Example 1**
#
# **Filtering the dataset**

# %%
df_example1= df[(df['job_title_short']=='Data Analyst') & (df['job_country'] =='United States')].copy()
df_example1
# Out:
#        job_title_short                                     job_title  \
# 36        Data Analyst                                  Data Analyst
# 68        Data Analyst                     Sr. Research Data Analyst
# 73        Data Analyst   Entry level / Systems Data Analyst (Remote)
# 79        Data Analyst                    Data Analyst/Report Writer
# 93        Data Analyst  IT Finance / TBM Data Analyst - Remote | WFH
# ...                ...                                           ...
# 785603    Data Analyst                           Junior Data Analyst
# 785626    Data Analyst                    Data Acquisition Associate
# 785685    Data Analyst                                  Data Analyst
# 785703    Data Analyst       Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst     Expert Business Data Analyst - Now Hiring
#
#             job_location               job_via job_schedule_type  \
# 36        Des Moines, IA       via Trabajo.org         Full-time
# ...

# %% [markdown]
# *removing NaN values in the salary year avg column*

# %%
df_example1.dropna(subset='salary_year_avg',inplace=True)

# %% [markdown]
# **Plotting Box**

# %%
df_example1['salary_year_avg'].plot(kind='box',vert=False)
plt.xlabel('Salary')
plt.title('Salary distribution for data analyst')
ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x,pos : f'${int(x/1000)}k'))

# %% [markdown]
# **Example 2**

# %%
job_titles = ['Data Analyst','Data Engineer','Data Scientist']
df_us = df[df['job_title_short'].isin(job_titles) & (df['job_country']=='United States')].copy()
df_us=df_us.dropna(subset='salary_year_avg')
job_list = [df_us[df_us['job_title_short']==job_title]['salary_year_avg'] for job_title in job_titles]
job_list
# Out:
# [109        89000.0
#  180        90250.0
#  410       133285.0
#  988        62623.0
#  1413       71300.0
#              ...
#  782637     70000.0
#  782798    111175.0
#  783588    125000.0
#  783866    115000.0
#  784882     87500.0
#  Name: salary_year_avg, Length: 4350, dtype: float64,
#  92        120000.0
#  146       129500.0
#  307       185000.0
#  339       195000.0
#  380        97500.0
#              ...
#  783111    125000.0
#  784102     90000.0
#  784191    217500.0
#  785624    139216.0
#  785641    150000.0
#  Name: salary_year_avg, Length: 2915, dtype: float64,
#  100       228222.0
#  116       114000.0
#  257       103128.0
#  450       157500.0
#  1257       70700.0
#              ...
#  785324    234500.0
#  785488    115000.0
#  785563    136400.0
#  785648    221875.0
#  785692    157500.0
#  Name: salary_year_avg, Length: 4553, dtype: float64]

# %%
plt.boxplot(job_list,tick_labels=job_titles,vert=False)
plt.title('Salary Distribution for Data Jobs')
plt.xlabel('Salary')
ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x,pos : f'${int(x/1000)}K'))
plt.xlim(0,600000)
plt.show()
