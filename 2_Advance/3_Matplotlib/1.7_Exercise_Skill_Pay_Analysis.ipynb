# %% [markdown]
# # Exercise : Skill Pay Analysis

# %%
# Import Libraries
from datasets import load_dataset
import ast
import pandas as pd
import matplotlib.pyplot as plt

# Load Dataset
raw = load_dataset('lukebarousse/data_jobs')
data = raw['train'].to_pandas()
df = data.copy()

# Data Cleaning
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)
df['job_skills'] = df['job_skills'].apply(lambda x :ast.literal_eval(x) if pd.notna(x) else x)

# %% [markdown]
# *Filtering Data Analyst jobs in US*

# %%
df_DA_US = df[(df['job_title_short']=='Data Analyst') & (df['job_country']=='United States')].copy()
df_DA_US
# Out:
#        job_title_short  ...                                    job_type_skills
# 36        Data Analyst  ...                                                NaN
# 68        Data Analyst  ...           {'programming': ['r'], 'sync': ['zoom']}
# 73        Data Analyst  ...  {'analyst_tools': ['word', 'excel', 'powerpoin...
# 79        Data Analyst  ...  {'analyst_tools': ['sas', 'word', 'excel'], 'p...
# 93        Data Analyst  ...  {'analyst_tools': ['power bi', 'excel', 'word'...
# ...                ...  ...                                                ...
# 785603    Data Analyst  ...  {'analyst_tools': ['excel'], 'other': ['flow']...
# 785626    Data Analyst  ...                      {'sync': ['microsoft teams']}
# 785685    Data Analyst  ...  {'analyst_tools': ['excel'], 'programming': ['...
# 785703    Data Analyst  ...                                                NaN
# 785705    Data Analyst  ...  {'analyst_tools': ['tableau'], 'programming': ...
#
# ...

# %% [markdown]
# *Unpacking the job skills list*

# %%
df_DA_US=df_DA_US.explode('job_skills')
df_DA_US
# Out:
#        job_title_short  ...                                    job_type_skills
# 36        Data Analyst  ...                                                NaN
# 68        Data Analyst  ...           {'programming': ['r'], 'sync': ['zoom']}
# 68        Data Analyst  ...           {'programming': ['r'], 'sync': ['zoom']}
# 73        Data Analyst  ...  {'analyst_tools': ['word', 'excel', 'powerpoin...
# 73        Data Analyst  ...  {'analyst_tools': ['word', 'excel', 'powerpoin...
# ...                ...  ...                                                ...
# 785685    Data Analyst  ...  {'analyst_tools': ['excel'], 'programming': ['...
# 785703    Data Analyst  ...                                                NaN
# 785705    Data Analyst  ...  {'analyst_tools': ['tableau'], 'programming': ...
# 785705    Data Analyst  ...  {'analyst_tools': ['tableau'], 'programming': ...
# 785705    Data Analyst  ...  {'analyst_tools': ['tableau'], 'programming': ...
#
# ...

# %% [markdown]
# *Deleting the NaN values in the salary_year_avg column*

# %%
df_DA_US=df_DA_US.dropna(subset='salary_year_avg')
df_DA_US
# Out:
#        job_title_short  ...                                    job_type_skills
# 109       Data Analyst  ...  {'analyst_tools': ['alteryx', 'tableau'], 'pro...
# 109       Data Analyst  ...  {'analyst_tools': ['alteryx', 'tableau'], 'pro...
# 109       Data Analyst  ...  {'analyst_tools': ['alteryx', 'tableau'], 'pro...
# 109       Data Analyst  ...  {'analyst_tools': ['alteryx', 'tableau'], 'pro...
# 180       Data Analyst  ...         {'analyst_tools': ['excel', 'powerpoint']}
# ...                ...  ...                                                ...
# 784882    Data Analyst  ...  {'analyst_tools': ['tableau', 'excel', 'altery...
# 784882    Data Analyst  ...  {'analyst_tools': ['tableau', 'excel', 'altery...
# 784882    Data Analyst  ...  {'analyst_tools': ['tableau', 'excel', 'altery...
# 784882    Data Analyst  ...  {'analyst_tools': ['tableau', 'excel', 'altery...
# 784882    Data Analyst  ...  {'analyst_tools': ['tableau', 'excel', 'altery...
#
# ...

# %% [markdown]
# *Grouping the job skills count and median salary*

# %%
df_US_group =df_DA_US.groupby('job_skills')['salary_year_avg'].agg(['count','median'])
df_US_group
# Out:
#             count     median
# job_skills
# airflow        44  116250.00
# airtable        5   90000.00
# alteryx       106  106281.25
# angular         8  107500.00
# ansible         1  159640.00
# ...           ...        ...
# wire            4   74250.00
# word          461   81194.75
# workfront       3   75000.00
# wrike           1   75000.00
# zoom           15   80740.00
#
# [170 rows x 2 columns]

# %% [markdown]
# *Sorting to find the high paying skills*

# %%
df_Top_Pay =df_US_group.sort_values('median',ascending=False).head(10)
df_Top_Pay
# Out:
#               count    median
# job_skills
# dplyr             2  196250.0
# bitbucket         3  189000.0
# gitlab            3  186000.0
# solidity          1  179000.0
# hugging face      1  175000.0
# couchbase         1  160515.0
# ansible           1  159640.0
# mxnet             2  149000.0
# cassandra         6  148250.0
# vmware            1  147500.0

# %% [markdown]
# *Sorting to find in-demand skills*

# %%
df_Top_skills = df_US_group.sort_values('count',ascending=False).head(10).sort_values('median',ascending=False)
df_Top_skills
# Out:
#             count    median
# job_skills
# python       1431  97500.00
# tableau      1364  92875.00
# r             893  92500.00
# sql server    286  92500.00
# sql          2508  91000.00
# sas           926  90000.00
# power bi      838  90000.00
# powerpoint    462  85000.00
# excel        1808  84392.00
# word          461  81194.75

# %% [markdown]
# *Plotting both finding in a single plot*

# %%
fig, ax = plt.subplots(2,1)
df_Top_Pay[::-1].plot(kind='barh',y='median',ax=ax[0],legend=False)

ax[0].set_title('Top 10 Highest Paid Skills For Data Analyst')
ax[0].set_xlabel('')
ax[0].set_ylabel('')
ax[0].xaxis.set_major_formatter(plt.FuncFormatter(lambda x,pos:f'${int(x/1000)}K'))

df_Top_skills[::-1].plot(kind='barh',y='median',ax=ax[1],legend=False)
ax[1].set_title('Top 10 Most In-Demand Skills For Data Analyst')
ax[1].set_xlabel('Median Salary (USD)')
ax[1].set_ylabel('')
ax[1].xaxis.set_major_formatter(plt.FuncFormatter(lambda x,pos:f'${int(x/1000)}K'))
ax[1].set_xlim(ax[0].get_xlim())

fig.tight_layout()
