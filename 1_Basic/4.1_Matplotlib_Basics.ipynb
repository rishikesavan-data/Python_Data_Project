# %% [markdown]
# # Matplotlib Basics

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Basic Graph

# %%
x=np.array([0.5,0.1])
y=x
plt.plot(x,y)

# %%
x=np.arange(0,5,0.1)
y=np.sin(x)
plt.plot(x,y)
